# %%
import pandas as pd

# %%
df_gbi = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/reddit_g_b_i.csv')

# %%
df_gbi
# Out:
#                         game_name  average_percentage_good  \
# 0         13 Sentinels: Aegis Rim                     40.0
# 1        A Plague Tale: Innocence                     20.0
# 2          A Plague Tale: Requiem                     30.0
# 3    Ace Combat 5: The Unsung War                     60.0
# 4                  Aeterna Noctis                     60.0
# ..                            ...                      ...
# 208                    Weird West                     20.0
# 209        World War Z: Aftermath                     30.0
# 210                     Wreckfest                     50.0
# 211         Yakuza: Like a Dragon                     40.0
# 212                eFootball 2022                     50.0
#
#      average_percentage_intermediate  average_percentage_bad
# 0                               60.0                     0.0
# 1                               40.0                    40.0
# 2                               30.0                    40.0
# ...

# %%
df_gbi['average_percentage_good'] = df_gbi['average_percentage_good'].astype(int)

# %%
df_gbi['average_percentage_bad'] = df_gbi['average_percentage_bad'].astype(int)
df_gbi['average_percentage_intermediate'] = df_gbi['average_percentage_intermediate'].astype(int)

# %%
df_gbi
# Out:
#                         game_name  average_percentage_good  \
# 0         13 Sentinels: Aegis Rim                       40
# 1        A Plague Tale: Innocence                       20
# 2          A Plague Tale: Requiem                       30
# 3    Ace Combat 5: The Unsung War                       60
# 4                  Aeterna Noctis                       60
# ..                            ...                      ...
# 208                    Weird West                       20
# 209        World War Z: Aftermath                       30
# 210                     Wreckfest                       50
# 211         Yakuza: Like a Dragon                       40
# 212                eFootball 2022                       50
#
#      average_percentage_intermediate  average_percentage_bad
# 0                                 60                       0
# 1                                 40                      40
# 2                                 30                      40
# ...

# %%
df_gbi.to_csv('reddit_g_b_i1.csv',index=False)
