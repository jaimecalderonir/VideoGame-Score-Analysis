# %%
import pandas as pd

# %%
df_ts = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/df11_total_sales.csv')

# %%
df_ts
# Out:
#                                          Title  \
# 0                PlayerUnknown's Battlegrounds
# 1                                         PUBG
# 2                        Red Dead Redemption 2
# 3                          Mario Kart 8 Deluxe
# 4                          Marvel's Spider-Man
# ...                                        ...
# 1064                      Guns, Gore & Cannoli
# 1065         ToeJam & Earl: Back in the Groove
# 1066  Twin Breaker: A Sacred Symbols Adventure
# 1067                                    Chippy
# 1068                               Feral Rites
#
#                            Publisher             Developer  Total Sales  \
# 0                   PUBG Corporation      PUBG Corporation     75000000
# 1                   PUBG Corporation      PUBG Corporation     75000000
# 2                     Rockstar Games      Rockstar Studios     65000000
# 3                           Nintendo          Nintendo EPD     62900000
# ...

# %%
# Lista de valores en formato de millones
valores = df_ts['Total Sales']

# Convertir a enteros
valores_convertidos = [int(float(valor[:-1]) * 1_000_000) for valor in valores]

df_ts['Total Sales'] = valores_convertidos
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 5
#       2 valores = df_ts['Total Sales']
#       4 # Convertir a enteros
# ----> 5 valores_convertidos = [int(float(valor[:-1]) * 1_000_000) for valor in valores]
#       7 df_ts['Total Sales'] = valores_convertidos
#
# TypeError: 'int' object is not subscriptable

# %%
df_ts['Total Sales'] = df_ts['Total Sales'].astype(int)

# %%
df_ts['Total Sales']
# Out:
# 0       75000000
# 1       75000000
# 2       65000000
# 3       62900000
# 4       51000000
#           ...
# 1116       20000
# 1117       10000
# 1118       10000
# 1119       10000
# 1120           0
# Name: Total Sales, Length: 1121, dtype: int64

# %%
df_ts['PAL Sales']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1116   NaN
# 1117   NaN
# 1118   NaN
# 1119   NaN
# 1120   NaN
# Name: PAL Sales, Length: 1121, dtype: float64

# %%
df_ts.columns
# Out:
# Index(['Title', 'Publisher', 'Developer', 'Total Sales', 'NA Sales',
#        'PAL Sales', 'Japan Sales', 'Other Sales', 'Release Date',
#        'Last Update', 'Year'],
#       dtype='object')

# %%
df_ts.drop(columns=['NA Sales','PAL Sales', 'Japan Sales', 'Other Sales'],inplace=True)

# %%
df_ts=df_ts.dropna()

# %%
df_ts['Year'] = df_ts['Year'].astype(str)

# %%
df_ts.to_csv('df11_total_sales1.csv',index=False)

# %%
df_os = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/df11_other_sales.csv')

# %%
# Lista de valores en formato de millones
valores = df_os['Other Sales']

# Convertir a enteros
valores_convertidosos = [int(float(valor[:-1]) * 1_000_000) for valor in valores]

df_os['Other Sales'] = valores_convertidosos

# %%
df_os['Other Sales'] = df_os['Other Sales'].astype(int)

# %%
df_os
# Out:
#                                                   Title           Publisher  \
# 0                             Call of Duty: Black Ops 3          Activision
# 1                  Red Dead Redemption 2Read the review      Rockstar Games
# 2                     Call of Duty: WWIIRead the review          Activision
# 3                                               FIFA 18           EA Sports
# 4                                               FIFA 17     Electronic Arts
# ...                                                 ...                 ...
# 1271  Go! Princess PreCure Sugar Oukoku to 6-nin no ...  Bandai Namco Games
# 1272           Zettai Meikyuu: Himitsu no Oya Yubi Hime               Views
# 1273                                          Natsumegu             Unknown
# 1274  Fushigi no Chronicle: Furikaerimasen Katsu Madewa      Spike Chunsoft
# 1275  Shinsouhan Heart no Kuni no Alice: Wonderful W...            Quinrose
#
# ...

# %%
df_os.drop(columns=['NA Sales','PAL Sales', 'Japan Sales', 'Total Sales'],inplace=True)

# %%
df_os = df_os.dropna()

# %%
df_os['Year'] = df_os['Year'].astype(str)
# Out:
# /var/folders/zc/6rc7nzhj13scy5qssxw2pjlh0000gn/T/ipykernel_38794/2674589905.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_os['Year'] = df_os['Year'].astype(str)

# %%
df_os.to_csv('df11_other_sales1.csv',index=False)

# %%
df_na = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/df11_na_sales.csv')

# %%
df_na
# Out:
#                                            Title         Publisher  \
# 0                      Call of Duty: Black Ops 3        Activision
# 1           Red Dead Redemption 2Read the review    Rockstar Games
# 2              Call of Duty: WWIIRead the review        Activision
# 3                                        FIFA 18         EA Sports
# 4                                        FIFA 17   Electronic Arts
# ...                                          ...               ...
# 2596  Street Fighter 30th Anniversary Collection            Capcom
# 2597                                Crazy Taxi 3           Unknown
# 2598                      Reveries: Seelenfänger        Rondomedia
# 2599                                   MotoGP 18  Milestone S.r.l.
# 2600                           Zero Time Dilemma    Spike Chunsoft
#
#                Developer  Total Sales NA Sales PAL Sales Japan Sales  \
# 0               Treyarch          NaN   15.09m     6.18m       6.05m
# ...

# %%
# Lista de valores en formato de millones
valores = df_na['NA Sales']

# Convertir a enteros
valores_convertidosna = [int(float(valor[:-1]) * 1_000_000) for valor in valores]

df_na['NA Sales'] = valores_convertidosna

# %%
df_na['NA Sales'] = df_na['NA Sales'].astype(int)

# %%
df_na.drop(columns=['Other Sales','PAL Sales', 'Japan Sales', 'Total Sales'],inplace=True)

# %%
df_na = df_na.dropna()

# %%
df_na['Year'] = df_na['Year'].astype(str)
# Out:
# /var/folders/zc/6rc7nzhj13scy5qssxw2pjlh0000gn/T/ipykernel_38794/2062740003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_na['Year'] = df_na['Year'].astype(str)

# %%
df_na.to_csv('df11_na_sales1.csv',index=False)

# %%
df_jap= pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/df11_jap_sales.csv')

# %%
df_jap['Japan Sales']
# Out:
#                                            Title         Publisher  \
# 0                      Call of Duty: Black Ops 3        Activision
# 1           Red Dead Redemption 2Read the review    Rockstar Games
# 2              Call of Duty: WWIIRead the review        Activision
# 3                                        FIFA 18         EA Sports
# 4                                        FIFA 17   Electronic Arts
# ...                                          ...               ...
# 1294  Street Fighter 30th Anniversary Collection            Capcom
# 1295                                Crazy Taxi 3           Unknown
# 1296                      Reveries: Seelenfänger        Rondomedia
# 1297                                   MotoGP 18  Milestone S.r.l.
# 1298                           Zero Time Dilemma    Spike Chunsoft
#
#                Developer  Total Sales NA Sales PAL Sales Japan Sales  \
# 0               Treyarch          NaN   15.09m     6.18m       6.05m
# ...

# %%
valores = df_jap['Japan Sales']

# Convertir a enteros
valores_convertidosja = [int(float(valor[:-1]) * 1_000_000) for valor in valores]

df_jap['Japan Sales'] = valores_convertidosja

# %%
df_jap['Japan Sales'] = df_jap['Japan Sales'].astype(int)

# %%
df_jap.drop(columns=['Other Sales','PAL Sales', 'NA Sales', 'Total Sales'],inplace=True)

# %%
df_jap = df_jap.dropna()

# %%
df_jap.dtypes
# Out:
# Title            object
# Publisher        object
# Developer        object
# Japan Sales       int64
# Release Date     object
# Last Update      object
# Year            float64
# dtype: object

# %%
df_jap['Year'] = df_jap['Year'].astype(str)
# Out:
# /var/folders/zc/6rc7nzhj13scy5qssxw2pjlh0000gn/T/ipykernel_38794/271201322.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jap['Year'] = df_jap['Year'].astype(str)

# %%
df_jap.to_csv('df11_jap_sales1.csv',index=False)

# %%
df_pal = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/df11_pal_sales.csv')

# %%
valores = df_pal['PAL Sales']

# Convertir a enteros
valores_convertidospa = [int(float(valor[:-1]) * 1_000_000) for valor in valores]

df_pal['PAL Sales'] = valores_convertidospa

# %%
df_pal['PAL Sales'] = df_pal['PAL Sales'].astype(int)

# %%
df_pal = df_pal.dropna()

# %%
df_pal.dtypes
# Out:
# Title           object
# Publisher       object
# Developer       object
# PAL Sales        int64
# Release Date    object
# Last Update     object
# Year            object
# dtype: object

# %%
df_pal.drop(columns=['Other Sales','Japan Sales', 'NA Sales', 'Total Sales'],inplace=True)

# %%
df_pal['Year'] = df_pal['Year'].astype(str)

# %%
df_pal.to_csv('df11_pal_sales1.csv',index=False)

# %%
df = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/df11_total_sales.csv')

# %%
df
# Out:
#                                          Title  \
# 0                PlayerUnknown's Battlegrounds
# 1                                         PUBG
# 2                        Red Dead Redemption 2
# 3                          Mario Kart 8 Deluxe
# 4                          Marvel's Spider-Man
# ...                                        ...
# 1116                      Guns, Gore & Cannoli
# 1117         ToeJam & Earl: Back in the Groove
# 1118  Twin Breaker: A Sacred Symbols Adventure
# 1119                                    Chippy
# 1120                               Feral Rites
#
#                            Publisher             Developer Total Sales  \
# 0                   PUBG Corporation      PUBG Corporation      75.00m
# 1                   PUBG Corporation      PUBG Corporation      75.00m
# 2                     Rockstar Games      Rockstar Studios      65.00m
# 3                           Nintendo          Nintendo EPD      62.90m
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/ws2_rawg.csv')

# %%
df
# Out:
#            id                                slug  \
# 0        3498                  grand-theft-auto-v
# 1        3328             the-witcher-3-wild-hunt
# 2        4200                            portal-2
# 3        4291     counter-strike-global-offensive
# 4        5286                         tomb-raider
# ...       ...                                 ...
# 35595  336822              akash-path-of-the-five
# 35596  336536        valkyria-chronicles-remaster
# 35597  334185  inazuma-eleven-3-team-ogre-attacks
# 35598  333151    digimon-world-re-digitize-decode
# 35599  333142                      diaboliklovers
#
#                                        name    released    tba  \
# 0                        Grand Theft Auto V  2013-09-17  False
# 1                  The Witcher 3: Wild Hunt  2015-05-18  False
# 2                                  Portal 2  2011-04-18  False
# 3          Counter-Strike: Global Offensive  2012-08-21  False
# ...
