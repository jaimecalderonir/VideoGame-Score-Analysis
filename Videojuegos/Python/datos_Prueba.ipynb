# %%
import pandas as pd

# %%
df_merge_clean_sales = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/df_merged_sales_clean.csv')

# %%
df_merge_clean_sales
# Out:
#     game_id                                    game_name    released    tba  \
# 0      3498                           Grand Theft Auto V  2013-09-17  False
# 1      3328                     The Witcher 3: Wild Hunt  2015-05-18  False
# 2      5679                  The Elder Scrolls V: Skyrim  2011-11-11  False
# 3      3070                                    Fallout 4  2015-11-09  False
# 4      2093                                 No Man's Sky  2016-08-09  False
# 5      5193                      Oddworld: Abe's Oddysee  1997-09-19  False
# 6     58813                              Resident Evil 2  2019-01-25  False
# 7    259801                            Final Fantasy VII  2020-04-10  False
# 8     35561                 Star Wars: Republic Commando  2005-03-01  False
# 9     54491                                        Quake  1996-06-22  False
# 10    23600                                   Diablo III  2012-05-15  False
# ...

# %%
df_reddit = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/reddit_g_b_i.csv')

# %%
df_reddit
# Out:
#                         game_name  average_percentage_good  \
# 0         13 Sentinels: Aegis Rim                     40.0
# 1        A Plague Tale: Innocence                     20.0
# 2          A Plague Tale: Requiem                     30.0
# 3    Ace Combat 5: The Unsung War                     60.0
# 4                  Aeterna Noctis                     60.0
# ..                            ...                      ...
# 208                    Weird West                     20.0
# 209        World War Z: Aftermath                     30.0
# 210                     Wreckfest                     50.0
# 211         Yakuza: Like a Dragon                     40.0
# 212                eFootball 2022                     50.0
#
#      average_percentage_intermediate  average_percentage_bad
# 0                               60.0                     0.0
# 1                               40.0                    40.0
# 2                               30.0                    40.0
# ...

# %%
df_merge_reddit = pd.merge(df_merge_clean_sales,df_reddit,on='game_name',how='inner')

# %%
pd.set_option('display.max_columns', None)

# %%
df_merge_reddit.drop(columns=['added', 'owned', 'tba', 'ratings_count'],inplace=True)

# %%
df_merge_reddit
# Out:
#    game_id                     game_name    released age rating       genre  \
# 0     3498            Grand Theft Auto V  2013-09-17     Mature      Action
# 1     3328      The Witcher 3: Wild Hunt  2015-05-18     Mature      Action
# 2     5679   The Elder Scrolls V: Skyrim  2011-11-11     Mature      Action
# 3     2093                  No Man's Sky  2016-08-09       Teen   Adventure
# 4    58813               Resident Evil 2  2019-01-25     Mature     Shooter
# 5    35561  Star Wars: Republic Commando  2005-03-01       Teen     Shooter
# 6    54491                         Quake  1996-06-22     Mature     Shooter
# 7    23600                    Diablo III  2012-05-15     Mature      Action
# 8    52670                    Ape Escape  1999-05-31   Everyone  Platformer
# 9    59315  Ace Combat 5: The Unsung War  2004-10-21     Mature  Simulation
#
#                                             subgenre  numero_plataformas  \
# ...

# %%
df_merge_reddit.to_csv('df_merge_total_prueba.csv',index=False)
