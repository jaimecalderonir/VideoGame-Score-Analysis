# %% [markdown]
# # Merge dfs

# %%
import pandas as pd
import numpy as np
import requests
import os

# %%
df_principal = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/df_clean_final.csv')

# %%
df_principal
# Out:
#      Unnamed: 0  game_id                                          game_name  \
# 0             0     3498                                 Grand Theft Auto V
# 1             1     3328                           The Witcher 3: Wild Hunt
# 2             2     5679                        The Elder Scrolls V: Skyrim
# 3             3       32                                          Destiny 2
# 4             4     3070                                          Fallout 4
# ..          ...      ...                                                ...
# 974        1100   795323                      Dead by Daylight - Hellraiser
# 975        1101   812169                                   SENSEs: Midnight
# 976        1103   795327                Dead by Daylight - Spark of Madness
# 977        1104   887670  Pre-purchase Romancing SaGa - Minstrel Song- R...
# 978        1106   968275                                       Neo Breakout
#
# ...

# %%
df_reddit_llm_g_b_i = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/reddit_g_b_i.csv')

# %%
df_reddit_llm_g_b_i
# Out:
#                         game_name  average_percentage_good  \
# 0         13 Sentinels: Aegis Rim                     40.0
# 1        A Plague Tale: Innocence                     20.0
# 2          A Plague Tale: Requiem                     30.0
# 3    Ace Combat 5: The Unsung War                     60.0
# 4                  Aeterna Noctis                     60.0
# ..                            ...                      ...
# 208                    Weird West                     20.0
# 209        World War Z: Aftermath                     30.0
# 210                     Wreckfest                     50.0
# 211         Yakuza: Like a Dragon                     40.0
# 212                eFootball 2022                     50.0
#
#      average_percentage_intermediate  average_percentage_bad
# 0                               60.0                     0.0
# 1                               40.0                    40.0
# 2                               30.0                    40.0
# ...

# %%
df_kaggle_ventas = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/vgsales.csv')

# %%
df_kaggle_ventas
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df_kaggle_ventas_2 = pd.read_csv('/Users/Jaimecalderon/Desktop/IRONHACK/Proyectos/Proyecto final/Videojuegos/vgsales 2.csv')

# %%
df_kaggle_ventas_2 = df_kaggle_ventas_2.dropna()

# %%
df_kaggle_ventas = df_kaggle_ventas.dropna()

# %%
df_kaggle_ventas
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## MErge scores

# %%
df_scores_todo = pd.merge(df_principal, df_reddit_llm_g_b_i, on='game_name', how='inner')

# %%
df_scores_todo
# Out:
#      Unnamed: 0  game_id                                    game_name  \
# 0             0     3498                           Grand Theft Auto V
# 1             1     3328                     The Witcher 3: Wild Hunt
# 2             2     5679                  The Elder Scrolls V: Skyrim
# 3             3       32                                    Destiny 2
# 4             5    41494                               Cyberpunk 2077
# ..          ...      ...                                          ...
# 208         923   963591  Fortnite Zero Build: No-Build Battle Royale
# 209         972   982815                              F1 Manager 2024
# 210         981   975453                                Rocket Racing
# 211         995   965121             Hammerwatch II: Anniversary Pack
# 212        1036   977220                            Fortnite Festival
#
#        released    tba age rating    genre                subgenre    owned  \
# ...

# %%
df_kaggle_ventas.rename(columns={'Name':'game_name'}, inplace=True)
# Out:
# /var/folders/zc/6rc7nzhj13scy5qssxw2pjlh0000gn/T/ipykernel_21998/350309228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kaggle_ventas.rename(columns={'Name':'game_name'}, inplace=True)

# %%
df_kaggle_ventas_2.rename(columns={'Name':'game_name'}, inplace=True)

# %%
df_kaggle_ventas
# Out:
#         Rank                                         game_name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df_kaggle_ventas[df_kaggle_ventas['game_name'] == 'Grand Theft Auto V']
# Out:
#       Rank           game_name Platform    Year   Genre             Publisher  \
# 16      17  Grand Theft Auto V      PS3  2013.0  Action  Take-Two Interactive
# 23      24  Grand Theft Auto V     X360  2013.0  Action  Take-Two Interactive
# 44      45  Grand Theft Auto V      PS4  2014.0  Action  Take-Two Interactive
# 197    198  Grand Theft Auto V     XOne  2014.0  Action  Take-Two Interactive
# 1896  1898  Grand Theft Auto V       PC  2015.0  Action  Take-Two Interactive
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 16        7.01      9.27      0.97         4.14         21.40
# 23        9.63      5.31      0.06         1.38         16.38
# 44        3.80      5.81      0.36         2.02         11.98
# 197       2.66      2.01      0.00         0.41          5.08
# 1896      0.36      0.64      0.00         0.08          1.08

# %%
df_suma = df_kaggle_ventas.groupby('game_name').agg({
    'NA_Sales': 'sum',
    'EU_Sales': 'sum',
    'JP_Sales': 'sum',
    'Other_Sales': 'sum',
    'Global_Sales': 'sum'
}).reset_index()

# %%
df_suma_2 = df_kaggle_ventas_2.groupby('game_name').agg({
    'NA_Sales': 'sum',
    'EU_Sales': 'sum',
    'JP_Sales': 'sum',
    'Other_Sales': 'sum',
    'Global_Sales': 'sum'
}).reset_index()

# %%
df_suma_2
# Out:
#                                      game_name  NA_Sales  EU_Sales  JP_Sales  \
# 0                                  '98 Koshien      0.15      0.10      0.12
# 1                   .hack//G.U. Vol.1//Rebirth      0.00      0.00      0.17
# 2                 .hack//G.U. Vol.2//Reminisce      0.11      0.09      0.00
# 3      .hack//G.U. Vol.2//Reminisce (jp sales)      0.00      0.00      0.16
# 4                .hack//G.U. Vol.3//Redemption      0.00      0.00      0.17
# ...                                        ...       ...       ...       ...
# 11320                       thinkSMART FAMILY!      0.03      0.00      0.00
# 11321               thinkSMART: Chess for Kids      0.01      0.00      0.00
# 11322                             uDraw Studio      1.67      0.58      0.00
# 11323             uDraw Studio: Instant Artist      0.09      0.10      0.00
# 11324             ¡Shin Chan Flipa en colores!      0.00      0.00      0.14
#
#        Other_Sales  Global_Sales
# ...

# %%
df_suma
# Out:
#                                      game_name  NA_Sales  EU_Sales  JP_Sales  \
# 0                                  '98 Koshien      0.15      0.10      0.12
# 1                   .hack//G.U. Vol.1//Rebirth      0.00      0.00      0.17
# 2                 .hack//G.U. Vol.2//Reminisce      0.11      0.09      0.00
# 3      .hack//G.U. Vol.2//Reminisce (jp sales)      0.00      0.00      0.16
# 4                .hack//G.U. Vol.3//Redemption      0.00      0.00      0.17
# ...                                        ...       ...       ...       ...
# 11320                       thinkSMART FAMILY!      0.03      0.00      0.00
# 11321               thinkSMART: Chess for Kids      0.01      0.00      0.00
# 11322                             uDraw Studio      1.67      0.58      0.00
# 11323             uDraw Studio: Instant Artist      0.09      0.10      0.00
# 11324             ¡Shin Chan Flipa en colores!      0.00      0.00      0.14
#
#        Other_Sales  Global_Sales
# ...

# %%
df_suma
# Out:
#                                      game_name  NA_Sales  EU_Sales  JP_Sales  \
# 0                                  '98 Koshien      0.15      0.10      0.12
# 1                   .hack//G.U. Vol.1//Rebirth      0.00      0.00      0.17
# 2                 .hack//G.U. Vol.2//Reminisce      0.11      0.09      0.00
# 3      .hack//G.U. Vol.2//Reminisce (jp sales)      0.00      0.00      0.16
# 4                .hack//G.U. Vol.3//Redemption      0.00      0.00      0.17
# ...                                        ...       ...       ...       ...
# 11320                       thinkSMART FAMILY!      0.03      0.00      0.00
# 11321               thinkSMART: Chess for Kids      0.01      0.00      0.00
# 11322                             uDraw Studio      1.67      0.58      0.00
# 11323             uDraw Studio: Instant Artist      0.09      0.10      0.00
# 11324             ¡Shin Chan Flipa en colores!      0.00      0.00      0.14
#
#        Other_Sales  Global_Sales
# ...

# %%
df_suma_sales_todo = pd.merge(df_scores_todo,df_suma,on='game_name',how='inner')

# %%
df_suma_sales_todo
# Out:
#    Unnamed: 0  game_id                     game_name    released    tba  \
# 0           0     3498            Grand Theft Auto V  2013-09-17  False
# 1           1     3328      The Witcher 3: Wild Hunt  2015-05-18  False
# 2           2     5679   The Elder Scrolls V: Skyrim  2011-11-11  False
# 3          14     2093                  No Man's Sky  2016-08-09  False
# 4          29    58813               Resident Evil 2  2019-01-25  False
# 5          48    35561  Star Wars: Republic Commando  2005-03-01  False
# 6          49    54491                         Quake  1996-06-22  False
# 7          76    23600                    Diablo III  2012-05-15  False
# 8         485    52670                    Ape Escape  1999-05-31  False
# 9         620    59315  Ace Combat 5: The Unsung War  2004-10-21  False
#
#   age rating       genre                                           subgenre  \
# 0     Mature      Action                                                 no
# ...

# %%
df_suma_sales_todo_k_2 = pd.merge(df_scores_todo,df_suma_2,on='game_name',how='inner')

# %%
df_suma_sales_todo_k_2
# Out:
#    Unnamed: 0  game_id                     game_name    released    tba  \
# 0           0     3498            Grand Theft Auto V  2013-09-17  False
# 1           1     3328      The Witcher 3: Wild Hunt  2015-05-18  False
# 2           2     5679   The Elder Scrolls V: Skyrim  2011-11-11  False
# 3          14     2093                  No Man's Sky  2016-08-09  False
# 4          29    58813               Resident Evil 2  2019-01-25  False
# 5          48    35561  Star Wars: Republic Commando  2005-03-01  False
# 6          49    54491                         Quake  1996-06-22  False
# 7          76    23600                    Diablo III  2012-05-15  False
# 8         485    52670                    Ape Escape  1999-05-31  False
# 9         620    59315  Ace Combat 5: The Unsung War  2004-10-21  False
#
#   age rating       genre                                           subgenre  \
# 0     Mature      Action                                                 no
# ...

# %% [markdown]
# ### df_s por plataforma

# %%
# Crear un diccionario para almacenar los DataFrames separados
dfs_por_plataforma = {platform: df_kaggle_ventas[df_kaggle_ventas['Platform'] == platform].reset_index(drop=True) 
                      for platform in df_kaggle_ventas['Platform'].unique()}

# Acceder a cada DataFrame por su plataforma
df_ps3 = dfs_por_plataforma['PS3']
df_x360 = dfs_por_plataforma['X360']
df_ps4 = dfs_por_plataforma['PS4']
df_xone = dfs_por_plataforma['XOne']
df_pc = dfs_por_plataforma['PC']
df_ps = dfs_por_plataforma['PS']

df_ps3
# Out:
#        Rank                                          game_name Platform  \
# 0        17                                 Grand Theft Auto V      PS3
# 1        35                         Call of Duty: Black Ops II      PS3
# 2        38                     Call of Duty: Modern Warfare 3      PS3
# 3        41                            Call of Duty: Black Ops      PS3
# 4        55                                     Gran Turismo 5      PS3
# ...     ...                                                ...      ...
# 1299  16453                        Hyperdimension Neptunia mk2      PS3
# 1300  16454  Shin Koihime Musou: Otome Taisen * Sangokushi ...      PS3
# 1301  16483                                Muv-Luv Alternative      PS3
# 1302  16524                           Akatsuki no Goei Trinity      PS3
# 1303  16544                                    Battle Fantasia      PS3
#
#         Year       Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df_ps = dfs_por_plataforma['PS']

# %%
df_merge_completo_ps = pd.merge(df_scores_todo, df_ps, on='game_name', how='inner')

# %%
df_merge_completo_ps
# Out:
#    Unnamed: 0  game_id        game_name    released    tba age rating  \
# 0          29    58813  Resident Evil 2  2019-01-25  False     Mature
# 1         485    52670       Ape Escape  1999-05-31  False   Everyone
#
#         genre           subgenre   owned  numero_plataformas  ...  Rank  \
# 0     Shooter  Adventure, Action  1512.0                   5  ...   152
# 1  Platformer                 no    60.0                   3  ...  1131
#
#    Platform    Year     Genre                    Publisher  NA_Sales  \
# 0        PS  1998.0    Action           Virgin Interactive      1.88
# 1        PS  1999.0  Platform  Sony Computer Entertainment      0.71
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      1.47      2.02         0.45          5.82
# 1      0.48      0.32         0.11          1.63
#
# [2 rows x 29 columns]

# %%
df_merge_completo_ps3 = pd.merge(df_scores_todo, df_ps3, on='game_name', how='inner')

# %%
df_merge_completo_ps3
# Out:
#    Unnamed: 0  game_id                    game_name    released    tba  \
# 0           0     3498           Grand Theft Auto V  2013-09-17  False
# 1           2     5679  The Elder Scrolls V: Skyrim  2011-11-11  False
# 2          76    23600                   Diablo III  2012-05-15  False
# 3         485    52670                   Ape Escape  1999-05-31  False
#
#   age rating       genre subgenre    owned  numero_plataformas  ...   Rank  \
# 0     Mature      Action       no  12151.0                   7  ...     17
# 1     Mature      Action      RPG   9518.0                   8  ...    127
# 2     Mature      Action      RPG    880.0                   9  ...    828
# 3   Everyone  Platformer       no     60.0                   3  ...  13439
#
#    Platform    Year         Genre                    Publisher  NA_Sales  \
# 0       PS3  2013.0        Action         Take-Two Interactive      7.01
# 1       PS3  2011.0  Role-Playing           Bethesda Softworks      2.55
# ...

# %%
df_merge_completo_ps4 = pd.merge(df_scores_todo, df_ps4, on='game_name', how='inner')

# %%
df_merge_completo_ps4
# Out:
#    Unnamed: 0  game_id                 game_name    released    tba  \
# 0           0     3498        Grand Theft Auto V  2013-09-17  False
# 1           1     3328  The Witcher 3: Wild Hunt  2015-05-18  False
# 2          14     2093              No Man's Sky  2016-08-09  False
# 3          76    23600                Diablo III  2012-05-15  False
#
#   age rating      genre                                           subgenre  \
# 0     Mature     Action                                                 no
# 1     Mature     Action                                                RPG
# 2       Teen  Adventure  Action, RPG, Simulation, Indie, Massively Mult...
# 3     Mature     Action                                                RPG
#
#      owned  numero_plataformas  ...  Rank  Platform    Year         Genre  \
# 0  12151.0                   7  ...    45       PS4  2014.0        Action
# 1  12003.0                   7  ...   332       PS4  2015.0  Role-Playing
# ...

# %%
df_merge_completo_xOne = pd.merge(df_scores_todo, df_xone, on='game_name', how='inner')

# %%
df_merge_completo_xOne
# Out:
#    Unnamed: 0  game_id                 game_name    released    tba  \
# 0           0     3498        Grand Theft Auto V  2013-09-17  False
# 1           1     3328  The Witcher 3: Wild Hunt  2015-05-18  False
# 2          76    23600                Diablo III  2012-05-15  False
#
#   age rating   genre subgenre    owned  numero_plataformas  ...  Rank  \
# 0     Mature  Action       no  12151.0                   7  ...   198
# 1     Mature  Action      RPG  12003.0                   7  ...  1607
# 2     Mature  Action      RPG    880.0                   9  ...  3138
#
#    Platform    Year         Genre             Publisher  NA_Sales  EU_Sales  \
# 0      XOne  2014.0        Action  Take-Two Interactive      2.66      2.01
# 1      XOne  2015.0  Role-Playing    Namco Bandai Games      0.66      0.47
# 2      XOne  2014.0  Role-Playing            Activision      0.35      0.24
#
#    JP_Sales  Other_Sales  Global_Sales
# 0       0.0         0.41          5.08
# ...

# %%
df_merge_completo_pc = pd.merge(df_scores_todo, df_pc, on='game_name', how='inner')

# %%
df_merge_completo_pc
# Out:
#    Unnamed: 0  game_id                     game_name    released    tba  \
# 0           0     3498            Grand Theft Auto V  2013-09-17  False
# 1           1     3328      The Witcher 3: Wild Hunt  2015-05-18  False
# 2           2     5679   The Elder Scrolls V: Skyrim  2011-11-11  False
# 3          48    35561  Star Wars: Republic Commando  2005-03-01  False
# 4          76    23600                    Diablo III  2012-05-15  False
#
#   age rating    genre subgenre    owned  numero_plataformas  ...   Rank  \
# 0     Mature   Action       no  12151.0                   7  ...   1898
# 1     Mature   Action      RPG  12003.0                   7  ...   3028
# 2     Mature   Action      RPG   9518.0                   8  ...    311
# 3       Teen  Shooter   Action   2390.0                   7  ...  13040
# 4     Mature   Action      RPG    880.0                   9  ...    182
#
#    Platform    Year         Genre             Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df_merge_completo_x360 = pd.merge(df_scores_todo, df_x360, on='game_name', how='inner')

# %%
df_merge_completo_x360
# Out:
#    Unnamed: 0  game_id                    game_name    released    tba  \
# 0           0     3498           Grand Theft Auto V  2013-09-17  False
# 1           2     5679  The Elder Scrolls V: Skyrim  2011-11-11  False
# 2          76    23600                   Diablo III  2012-05-15  False
#
#   age rating   genre subgenre    owned  numero_plataformas  ...  Rank  \
# 0     Mature  Action       no  12151.0                   7  ...    24
# 1     Mature  Action      RPG   9518.0                   8  ...    76
# 2     Mature  Action      RPG    880.0                   9  ...  1318
#
#    Platform    Year         Genre             Publisher  NA_Sales  EU_Sales  \
# 0      X360  2013.0        Action  Take-Two Interactive      9.63      5.31
# 1      X360  2011.0  Role-Playing    Bethesda Softworks      5.03      2.86
# 2      X360  2013.0  Role-Playing            Activision      0.89      0.44
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      0.06         1.38         16.38
# ...
